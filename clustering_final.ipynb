# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

try:
    df1 = pd.read_csv("rezultati_text.csv")
    df2 = pd.read_csv("rezultati_all.csv")
    df3 = pd.read_csv("rezultati_svd.csv")
    
    algoritmi = df1['Algoritam'].values

    master_data = {
        'Algoritam': algoritmi,
        'Samo Tekst': df1['Score'].values,
        'Svi Atributi': df2['Score'].values,
        'Redukovani (SVD)': df3['Score'].values
    }

    df_finalna_tabela = pd.DataFrame(master_data)

    print("\n--- FINALNA TABELA REZULTATA ---")
    print(df_finalna_tabela.to_string(index=False))

    plt.figure(figsize=(12, 6))
    sns.barplot(x='Algoritam', y='Score', hue='Set_Podataka', data=df_master, palette='coolwarm')
    plt.title('Poređenje performansi algoritama po setovima podataka', fontsize=14)
    plt.ylabel('Silhouette Score')
    plt.legend(title='Tip podataka', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.grid(axis='y', linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(10, 6))
    sns.heatmap(pivot_table, annot=True, cmap="YlGnBu", fmt=".4f", linewidths=.5)
    plt.title('Heatmap: Intenzitet kvaliteta klasterovanja')
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(8, 6))
    sns.boxplot(x='Set_Podataka', y='Score', hue='Set_Podataka', data=df_master, palette='Set2', legend=False)
    plt.title('Distribucija rezultata po setovima podataka')
    plt.ylabel('Silhouette Score')
    plt.grid(axis='y', linestyle=':', alpha=0.5)
    plt.tight_layout()
    plt.show()

    najbolji_red = df_master.loc[df_master['Score'].idxmax()]
    print(f"\nZAKLJUČAK:")
    print(f"Najbolje performanse ostvario je algoritam {najbolji_red['Algoritam']} ")
    print(f"korišćenjem {najbolji_red['Set_Podataka']} pristupa sa Silhouette skorom od {najbolji_red['Score']:.4f}.")

except FileNotFoundError:
    print("GRESKA: CSV fajlovi nisu pronadjeni. Proveri da li si pokrenula prva tri fajla!")
# Out:
# --- FINALNA TABELA REZULTATA ---
#     Algoritam  Samo Tekst  Svi Atributi  Redukovani (SVD)
#        KMeans    0.008745      0.230919          0.095336
#     MiniBatch   -0.003865      0.025346          0.074020
# Agglomerative    0.000253      0.383678          0.078420
#      Spectral    0.005373      0.235673          0.095870
#        DBSCAN    0.000000      0.000000          0.152041
# ZAKLJUČAK:
# Najbolje performanse ostvario je algoritam Agglomerative
# korišćenjem 2. svi atributi pristupa sa Silhouette skorom od 0.3837.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 6
#       4 # 1. Koristimo PCA da smanjimo podatke na 3 dimenzije (umesto na 2)
#       5 pca_3d = PCA(n_components=3)
# ----> 6 X_3d = pca_3d.fit_transform(X_reduced)
#       8 # 2. Pravimo DataFrame za lakše crtanje
#       9 df_3d = pd.DataFrame(X_3d, columns=['PC1', 'PC2', 'PC3'])
#
# NameError: name 'X_reduced' is not defined
