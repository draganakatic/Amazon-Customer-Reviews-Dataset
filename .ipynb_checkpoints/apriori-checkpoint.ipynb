# %%
import pandas as pd
import time
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split

import os

# Kreiranje foldera za grafike ako ne postoji
output_dir = "grafici_apriori"
os.makedirs(output_dir, exist_ok=True)

# %%
t0 = time.time()
def log(msg):
    print(f"[{time.time()-t0:6.1f}s] {msg}", flush=True)

# %% [markdown]
# <H3>Ucitavanje i uzrokovanje

# %%
data = pd.read_csv("../Reviews.csv")

# %%
df, _ = train_test_split(
    data,
    train_size=50000,
    stratify=data["Score"],
    random_state=42
)

# %%
df = df.drop_duplicates(subset=["UserId", "ProductId"])

# %% [markdown]
# <h3>Formiranje transakcija
# <h5> Transakcije = skup proizvoda koje je isti korisnik ocenio

# %%
transactions = (
    df.groupby("UserId")["ProductId"]
      .apply(lambda s: list(pd.unique(s)))
      .tolist()
)

log(f"Ukupno korisnika (transakcija): {len(transactions):,}")

lens = pd.Series([len(t) for t in transactions])
print("\nStatistika duzine transakcija:")
print(lens.describe())
print("Korisnika sa 1 proizvodom:", (lens == 1).sum())
print("Korisnika sa >=2 proizvoda:", (lens >= 2).sum())
# Out:
# [ 442.2s] Ukupno korisnika (transakcija): 40,243
#
# Statistika duzine transakcija:
# count    40243.000000
# mean         1.239992
# std          0.894101
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max         41.000000
# dtype: float64
# Korisnika sa 1 proizvodom: 34481
# Korisnika sa >=2 proizvoda: 5762

# %% [markdown]
# <h4>Zadrzavaju se samo korisnici sa >= 2 proizvoda

# %%
transactions2 = [t for t in transactions if len(t) >= 2]
log(f"Broj transakcija nakon filtriranja: {len(transactions2):,}")
# Out:
# [ 446.7s] Broj transakcija nakon filtriranja: 5,762

# %% [markdown]
# <h3>Apriori

# %%
te = TransactionEncoder()
te_ary = te.fit(transactions2).transform(transactions2)
basket = pd.DataFrame(te_ary, columns=te.columns_)

# %%
min_support = 0.001   
log(f"Pokrecem Apriori (min_support={min_support})...")

freq = apriori(
    basket,
    min_support=min_support,
    use_colnames=True,
    max_len=2,
    low_memory=True
)

freq["itemset_len"] = freq["itemsets"].apply(len)
log(f"Ukupno cistih itemset-ova: {len(freq):,}")
log(f"Parovi (len=2): {(freq['itemset_len'] == 2).sum():,}")
# Out:
# [ 450.3s] Pokrecem Apriori (min_support=0.001)...
# [ 450.9s] Ukupno cistih itemset-ova: 601
# [ 450.9s] Parovi (len=2): 32

# %%
rules = association_rules(freq, metric="lift", min_threshold=1.1)
log(f"Ukupno pravila: {len(rules):,}")
# Out:
# [ 451.4s] Ukupno pravila: 64

# %% [markdown]
# <H3>Prikaz rezultata

# %%
if len(rules) == 0:
    print("\nNema pravila za izabrane pragove.")
else:
    def fs(s):
        return ", ".join(sorted(list(s)))

    rules_display = rules.copy()
    rules_display["antecedents_str"] = rules["antecedents"].apply(fs)
    rules_display["consequents_str"] = rules["consequents"].apply(fs)
    rules_display = rules_display.sort_values(["lift", "confidence"], ascending=False)

    print("\nTOP 10 ASOCIJATIVNIH PRAVILA:")
    print(rules_display[["antecedents_str", "consequents_str",
                          "support", "confidence", "lift"]].head(10).to_string(index=False))

    # ── Scatter plot: Support vs Confidence ──────────────────────────
    fig, ax = plt.subplots(figsize=(10, 6))
    sc = ax.scatter(rules['support'], rules['confidence'],
                    c=rules['lift'], cmap='viridis', s=100, zorder=3)
    plt.colorbar(sc, ax=ax, label='Lift')
    ax.set_xlabel('Support')
    ax.set_ylabel('Confidence')
    ax.set_title('Pravila pridruživanja: Support vs Confidence')
    ax.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, "apriori_scatter.png"), dpi=150, bbox_inches='tight')
    plt.show()

    # ── Mrežni dijagram ───────────────────────────────────────────────
    fig, ax = plt.subplots(figsize=(14, 9))
    G = nx.DiGraph()

    for i, row in rules_display.head(10).iterrows():
        G.add_edge(row['antecedents_str'], row['consequents_str'],
                   weight=row['lift'], confidence=row['confidence'])

    pos = nx.circular_layout(G)

    nx.draw_networkx_nodes(G, pos, node_color='#4C9BE8',
                           node_size=4000, alpha=0.9, ax=ax)

    # Duži ID-ovi se prelamaju u dva reda radi čitljivosti
    labels = {n: n.replace(", ", "\n") for n in G.nodes()}
    nx.draw_networkx_labels(G, pos, labels=labels,
                            font_size=8, font_weight='bold', ax=ax)

    edges = G.edges(data=True)
    widths = [d['confidence'] * 4 for _, _, d in edges]
    nx.draw_networkx_edges(G, pos, width=widths,
                           edge_color='#555555', arrows=True,
                           arrowsize=20, connectionstyle='arc3,rad=0.1',
                           ax=ax)

    ax.set_title("Mrežni dijagram povezanosti proizvoda (top 10 pravila)\n"
                 "Debljina ivice proporcionalna confidence vrednosti", fontsize=12)
    ax.axis('off')
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, "apriori_network.png"), dpi=150, bbox_inches='tight')
    plt.show()
# Out:
# TOP 10 ASOCIJATIVNIH PRAVILA:
# antecedents_str consequents_str  support  confidence       lift
#      B000KV7ZGQ      B000KV61FC 0.001388    0.800000 460.960000
#      B000KV61FC      B000KV7ZGQ 0.001388    0.800000 460.960000
#      B001VIY8BW      B003WK0D8O 0.001041    0.666667 426.814815
#      B003WK0D8O      B001VIY8BW 0.001041    0.666667 426.814815
#      B007Y59HVM      B005ZBZLT4 0.001041    0.600000 345.720000
#      B005ZBZLT4      B007Y59HVM 0.001041    0.600000 345.720000
#      B0029ZAOW8      B003QNJYXM 0.001215    0.700000 336.116667
#      B003QNJYXM      B0029ZAOW8 0.001215    0.583333 336.116667
#      B001J9QBU4      B003JA5KLM 0.001041    0.666667 320.111111
#      B003JA5KLM      B001J9QBU4 0.001041    0.500000 320.111111
