# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

import re
import string
import nltk
from nltk.stem import WordNetLemmatizer

import plotly.express as px
from sklearn.feature_extraction.text import TfidfVectorizer, ENGLISH_STOP_WORDS
from sklearn.cluster import KMeans, MiniBatchKMeans, DBSCAN, AgglomerativeClustering, SpectralClustering
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
from sklearn.preprocessing import Normalizer
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import os
# Kreiranje foldera za grafike ako ne postoji
output_dir = "grafici_text_only"
os.makedirs(output_dir, exist_ok=True)

# SAMO PRI PRVOM POKRETANJU, KASNIJE MOGU DA SE ZAKOMENTARISU: 
nltk.download('wordnet')
nltk.download('omw-1.4')

lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\draga\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\draga\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# <h4>Pomocne funkcije</h4>

# %%
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'<.*?>', '', text)
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
    text = re.sub(r'\d+', '', text)
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = re.sub(r'\s+', ' ', text).strip()
    tokens = text.split()
    tokens = [lemmatizer.lemmatize(t) for t in tokens]
    return ' '.join(tokens)


def get_metrics(X, labels, name, silhouette_metric="cosine"):
    n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
    if n_clusters < 2:
        return [name, n_clusters, np.nan, np.nan, np.nan]

    mask = labels != -1
    if mask.sum() < 2:
        return [name, n_clusters, np.nan, np.nan, np.nan]

    s = silhouette_score(X[mask], labels[mask], metric=silhouette_metric)
    db = davies_bouldin_score(X[mask], labels[mask])
    ch = calinski_harabasz_score(X[mask], labels[mask])
    return [name, n_clusters, s, db, ch]

# %% [markdown]
# <h4>Ucitavanje i uzrokovanje podataka

# %%
cols_to_use = ['Text', 'Score']
data = pd.read_csv('../Reviews.csv', usecols=cols_to_use)
data = data.dropna(subset=cols_to_use)

# Isti pristup kao u clustering_all - 10000 redova, stratifikovano po Score
df, _ = train_test_split(
    data,
    train_size=10000,
    stratify=data["Score"],
    random_state=42
)
df = df.reset_index(drop=True)

print(f"Konačan broj redova za analizu: {len(df)}")
print("Ciscenje i lemmatizacija teksta (ovo moze potrajati)...")
df['Cleaned_Text'] = df['Text'].apply(clean_text)
# Out:
# Konačan broj redova za analizu: 10000
# Ciscenje i lemmatizacija teksta (ovo moze potrajati)...

# %% [markdown]
# <h4>Vektorizaija teksta

# %%
custom_stop = list(ENGLISH_STOP_WORDS) + ['wa', 'ha', 'doe', 'ca']

tfidf = TfidfVectorizer(
    max_features=1000,
    stop_words=custom_stop,
    ngram_range=(1, 2),
    min_df=5
)
X_text = tfidf.fit_transform(df['Cleaned_Text']).toarray()

# Normalizacija
X_final = Normalizer().fit_transform(X_text)

print(f"Dimenzija podataka (Samo Tekst): {X_final.shape}")
# Out:
# Dimenzija podataka (Samo Tekst): (10000, 1000)

# %% [markdown]
# <h4>Odredjivanje optimalnog k - Elbow i Silhouette metoda

# %%
K_range = range(2, 16)
inertias = []
sil_cos = []

for k in K_range:
    km_tmp = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels_tmp = km_tmp.fit_predict(X_final)
    inertias.append(km_tmp.inertia_)
    sil_cos.append(silhouette_score(X_final, labels_tmp, metric="cosine"))

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(list(K_range), inertias, marker='o')
plt.title("Elbow (Inertia) — KMeans (Samo Tekst)")
plt.xlabel("K")
plt.ylabel("Inertia")
plt.grid(True, alpha=0.3)

plt.subplot(1, 2, 2)
plt.plot(list(K_range), sil_cos, marker='o')
plt.title("Silhouette (cosine) — KMeans (Samo Tekst)")
plt.xlabel("K")
plt.ylabel("Silhouette")
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(output_dir,"elbow_silhouette_textonly.png"), dpi=150)
plt.show()

optimal_k = min(list(K_range)[int(np.argmax(sil_cos))], 8)
print(f"Optimalan broj klastera (po max Silhouette cosine): K={optimal_k}")
# Out:
# Optimalan broj klastera (po max Silhouette cosine): K=8

# %% [markdown]
# <h3>Klasterovanje - svi algoritmi sa optimalnim k

# %%
all_results = []

km = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
labels_km = km.fit_predict(X_final)
all_results.append(get_metrics(X_final, labels_km, f"KMeans(k={optimal_k})", silhouette_metric="cosine"))

mb = MiniBatchKMeans(n_clusters=optimal_k, random_state=42, batch_size=100, n_init=10)
labels_mb = mb.fit_predict(X_final)
all_results.append(get_metrics(X_final, labels_mb, f"MiniBatchKMeans(k={optimal_k})", silhouette_metric="cosine"))

agg = AgglomerativeClustering(n_clusters=optimal_k)
labels_agg = agg.fit_predict(X_final)
all_results.append(get_metrics(X_final, labels_agg, f"Agglomerative(k={optimal_k})", silhouette_metric="cosine"))

spec = SpectralClustering(n_clusters=optimal_k, affinity='nearest_neighbors', random_state=42)
labels_spec = spec.fit_predict(X_final)
all_results.append(get_metrics(X_final, labels_spec, f"Spectral(k={optimal_k})", silhouette_metric="cosine"))

#DBSCAN - bez fiksnog K
db_model = DBSCAN(eps=0.4, min_samples=3)
labels_db = db_model.fit_predict(X_final)
all_results.append(get_metrics(X_final, labels_db, "DBSCAN(eps=0.4,min_samples=3)", silhouette_metric="cosine"))

# %% [markdown]
# <h3>Klasterovanje - svi algoritmi sa k = 5 (motivisano time sto imamo 5 ocena)

# %%
km5 = KMeans(n_clusters=5, random_state=42, n_init=10)
labels_km5 = km5.fit_predict(X_final)
all_results.append(get_metrics(X_final, labels_km5, "KMeans(k=5)", silhouette_metric="cosine"))

mb5 = MiniBatchKMeans(n_clusters=5, random_state=42, batch_size=100, n_init=10)
labels_mb5 = mb5.fit_predict(X_final)
all_results.append(get_metrics(X_final, labels_mb5, "MiniBatchKMeans(k=5)", silhouette_metric="cosine"))

agg5 = AgglomerativeClustering(n_clusters=5)
labels_agg5 = agg5.fit_predict(X_final)
all_results.append(get_metrics(X_final, labels_agg5, "Agglomerative(k=5)", silhouette_metric="cosine"))

spec5 = SpectralClustering(n_clusters=5, affinity='nearest_neighbors', random_state=42)
labels_spec5 = spec5.fit_predict(X_final)
all_results.append(get_metrics(X_final, labels_spec5, "Spectral(k=5)", silhouette_metric="cosine"))

# %% [markdown]
# <h4>Prikaz rezultata

# %%
df_res = pd.DataFrame(
    all_results,
    columns=['Algoritam', 'n_clusters', 'Silhouette', 'Davies-Bouldin', 'Calinski-Harabasz']
)

print("\n--- REZULTATI: SAMO TEKST ---")
print(df_res.to_string(index=False))

df_res.to_csv("rezultati_textonly.csv", index=False)
print("\nSacuvano: rezultati_textonly.csv")
# Out:
# --- REZULTATI: SAMO TEKST ---
#                     Algoritam  n_clusters  Silhouette  Davies-Bouldin  Calinski-Harabasz
#                   KMeans(k=8)           8    0.037727        7.529323          75.943238
#          MiniBatchKMeans(k=8)           8    0.033318        6.853312          69.521622
#            Agglomerative(k=8)           8    0.012436        4.695250          57.985645
#                 Spectral(k=8)           8   -0.007530        3.213591          26.727738
# DBSCAN(eps=0.4,min_samples=3)          14    0.927178        0.099301         761.144653
#                   KMeans(k=5)           5    0.032267        6.553034          96.594014
#          MiniBatchKMeans(k=5)           5    0.031645        5.509502          95.332222
#            Agglomerative(k=5)           5    0.013248        5.226319          75.044494
#                 Spectral(k=5)           5   -0.011269        2.873070          21.191393
#
# Sacuvano: rezultati_textonly.csv

# %% [markdown]
# <h4>Analiza DBSCAN - raspodela klastera

# %%
print("\n=== DBSCAN raspodela klastera (ukljucujuci sum = -1) ===")
dbscan_counts = pd.Series(labels_db).value_counts().sort_index()
print(dbscan_counts)
n_noise = (labels_db == -1).sum()
n_total = len(labels_db)
print(f"\nBroj sum tacaka (label=-1): {n_noise} ({100*n_noise/n_total:.1f}%)")
print(f"Napomena: Visok Silhouette score kod DBSCAN moze biti misleading")
print(f"ako jedan klaster sadrzi veliku vecinu tacaka.")
# Out:
# === DBSCAN raspodela klastera (ukljucujuci sum = -1) ===
# -1     9956
#  0        3
#  1        3
#  2        3
#  3        3
#  4        5
#  5        3
#  6        3
#  7        3
#  8        3
#  9        3
#  10       3
#  11       3
#  12       3
#  13       3
# Name: count, dtype: int64
#
# Broj sum tacaka (label=-1): 9956 (99.6%)
# Napomena: Visok Silhouette score kod DBSCAN moze biti misleading
# ako jedan klaster sadrzi veliku vecinu tacaka.

# %% [markdown]
# <h4>Analiza - crosstab i top reci

# %%
df["cluster_opt"] = labels_km
df["cluster_k5"] = labels_km5

print(f"\n=== Crosstab: cluster (K={optimal_k}) × Score (brojevi) ===")
print(pd.crosstab(df["cluster_opt"], df["Score"]))

print(f"\n=== Crosstab: cluster (K={optimal_k}) × Score (procenti po klasteru) ===")
ct_score_opt = pd.crosstab(df["cluster_opt"], df["Score"], normalize="index")
print(ct_score_opt)

print("\n=== Crosstab: cluster (K=5) × Score (procenti po klasteru) ===")
ct_score_k5 = pd.crosstab(df["cluster_k5"], df["Score"], normalize="index")
print(ct_score_k5)

# Top reci po klasterima - optimalni K
feature_names = np.array(tfidf.get_feature_names_out())

print(f"\nTop reci po klasterima (K={optimal_k}):")
text_centers_opt = km.cluster_centers_[:, :1000]
for i in range(optimal_k):
    top_indices = text_centers_opt[i].argsort()[::-1][:10]
    top_words = feature_names[top_indices]
    print(f"\nKlaster {i}: {', '.join(top_words)}")

# Top reci po klasterima - K=5
print("\nTop reci po klasterima (K=5):")
text_centers_k5 = km5.cluster_centers_[:, :1000]
for i in range(5):
    top_indices = text_centers_k5[i].argsort()[::-1][:10]
    top_words = feature_names[top_indices]
    print(f"\nKlaster {i}: {', '.join(top_words)}")

# Statistika po klasterima
print(f"\nStatistika po klasterima (K={optimal_k}):")
statistika_opt = df.groupby('cluster_opt')[['Score']].mean()
print(statistika_opt)

print("\nStatistika po klasterima (K=5):")
statistika_k5 = df.groupby('cluster_k5')[['Score']].mean()
print(statistika_k5)

print("\nBroj recenzija po klasterima (K=optimal):")
print(df['cluster_opt'].value_counts())

print("\nBroj recenzija po klasterima (K=5):")
print(df['cluster_k5'].value_counts())
# Out:
# === Crosstab: cluster (K=8) × Score (brojevi) ===
# Score          1    2    3    4     5
# cluster_opt
# 0            300  152  196  435  2350
# 1             73   27   40  108   473
# 2             47   32   57  104   459
# 3             37   19   23   34   195
# 4             44   37   41   71   348
# 5            155   74   76  142   695
# 6             70   57   89  154   628
# 7            193  126  228  371  1240
#
# === Crosstab: cluster (K=8) × Score (procenti po klasteru) ===
# Score               1         2         3         4         5
# cluster_opt
# 0            0.087387  0.044276  0.057093  0.126711  0.684532
# 1            0.101248  0.037448  0.055479  0.149792  0.656033
# 2            0.067239  0.045780  0.081545  0.148784  0.656652
# 3            0.120130  0.061688  0.074675  0.110390  0.633117
# 4            0.081331  0.068392  0.075786  0.131238  0.643253
# 5            0.135727  0.064799  0.066550  0.124343  0.608581
# 6            0.070140  0.057114  0.089178  0.154309  0.629259
# 7            0.089435  0.058387  0.105653  0.171918  0.574606
#
# === Crosstab: cluster (K=5) × Score (procenti po klasteru) ===
# Score              1         2         3         4         5
# cluster_k5
# 0           0.065395  0.043597  0.079019  0.148501  0.663488
# 1           0.103282  0.039575  0.056950  0.145753  0.654440
# 2           0.074675  0.055195  0.079004  0.124459  0.666667
# 3           0.099106  0.054261  0.073412  0.141877  0.631344
# 4           0.071154  0.057692  0.096154  0.149038  0.625962
#
# Top reci po klasterima (K=8):
#
# Klaster 0: love, great, good, amazon, store, price, just, time, buy, best
#
# Klaster 1: dog, treat, food, dog love, love, dog food, like, chew, great, product
#
# Klaster 2: tea, green tea, green, flavor, taste, like, good, drink, bag, cup
#
# Klaster 3: cat, food, cat food, cat love, eat, like, love, canned, treat, chicken
#
# Klaster 4: bar, chocolate, peanut, taste, like, good, peanut butter, butter, snack, love
#
# Klaster 5: product, great, good, price, great product, use, love, taste, amazon, like
#
# Klaster 6: coffee, cup, flavor, like, strong, taste, good, bold, roast, cup coffee
#
# Klaster 7: taste, like, flavor, good, chip, just, water, great, really, drink
#
# Top reci po klasterima (K=5):
#
# Klaster 0: tea, green tea, green, flavor, taste, like, good, drink, bag, cup
#
# Klaster 1: dog, food, treat, cat, love, dog love, dog food, like, eat, product
#
# Klaster 2: bar, chocolate, chip, taste, like, peanut, good, love, flavor, snack
#
# Klaster 3: product, good, great, taste, like, love, flavor, just, make, price
#
# Klaster 4: coffee, cup, flavor, like, strong, taste, good, bold, roast, cup coffee
#
# Statistika po klasterima (K=8):
#                 Score
# cluster_opt
# 0            4.276726
# 1            4.221914
# 2            4.281831
# 3            4.074675
# 4            4.186691
# 5            4.005254
# 6            4.215431
# 7            4.083874
#
# Statistika po klasterima (K=5):
#                Score
# cluster_k5
# 0           4.301090
# 1           4.208494
# 2           4.253247
# 3           4.152091
# 4           4.200962
#
# Broj recenzija po klasterima (K=optimal):
# cluster_opt
# 0    3433
# 7    2158
# 5    1142
# 6     998
# 1     721
# 2     699
# 4     541
# 3     308
# Name: count, dtype: int64
#
# Broj recenzija po klasterima (K=5):
# cluster_k5
# 3    6266
# 4    1040
# 1    1036
# 2     924
# 0     734
# Name: count, dtype: int64

# %% [markdown]
# <h3>Vizualizacije

# %%
# --- Heatmap Score distribucija - optimalni K ---
plt.figure(figsize=(8, 5))
sns.heatmap(ct_score_opt, annot=True, fmt=".2f", cmap="Blues")
plt.title(f"Distribucija Score po klasterima (KMeans, K={optimal_k}) — Samo Tekst")
plt.xlabel("Score")
plt.ylabel("Klaster")
plt.tight_layout()
plt.savefig(os.path.join(output_dir,"heatmap_score_opt_textonly.png"), dpi=150)
plt.show()

# --- Heatmap Score distribucija - K=5 ---
plt.figure(figsize=(10, 6))
sns.heatmap(ct_score_k5, annot=True, fmt=".2f", cmap="Greens")
plt.title("Distribucija Score po klasterima (KMeans, K=5) — Samo Tekst")
plt.xlabel("Score")
plt.ylabel("Klaster")
plt.tight_layout()
plt.savefig(os.path.join(output_dir,"heatmap_score_k5_textonly.png"), dpi=150)
plt.show()

# --- Silhouette barplot - svi algoritmi ---
plt.figure(figsize=(12, 5))
sns.barplot(x='Algoritam', y='Silhouette', data=df_res, hue='Algoritam', palette='magma', legend=False)
plt.title('Silhouette Score - Samo Tekst')
plt.xticks(rotation=30, ha='right')
plt.tight_layout()
plt.savefig(os.path.join(output_dir,"silhouette_textonly.png"), dpi=150)
plt.show()

# --- 2D PCA Vizualizacija - optimalni K ---
pca_2d = PCA(n_components=2)
coords_pca = pca_2d.fit_transform(X_final)

plt.figure(figsize=(10, 6))
sns.scatterplot(x=coords_pca[:, 0], y=coords_pca[:, 1], hue=labels_km, palette='magma', alpha=0.7)
plt.title(f"2D PCA prikaz klastera (KMeans, K={optimal_k}) — Samo Tekst")
plt.tight_layout()
plt.savefig(os.path.join(output_dir,"pca_2d_opt_textonly.png"), dpi=150)
plt.show()

# --- 2D PCA Vizualizacija - K=5 ---
plt.figure(figsize=(10, 6))
sns.scatterplot(x=coords_pca[:, 0], y=coords_pca[:, 1], hue=labels_km5, palette='tab10', alpha=0.7)
plt.title("2D PCA prikaz klastera (KMeans, K=5) — Samo Tekst")
plt.tight_layout()
plt.savefig(os.path.join(output_dir,"pca_2d_k5_textonly.png"), dpi=150)
plt.show()

# --- 2D t-SNE Vizualizacija (na uzorku od 2000 zbog brzine) ---
print("\nt-SNE vizualizacija (moze potrajati ~2-3 minuta)...")
sample_idx = np.random.choice(len(X_final), size=2000, replace=False)
X_tsne_sample = X_final[sample_idx]
labels_tsne_opt = labels_km[sample_idx]
labels_tsne_k5 = labels_km5[sample_idx]

tsne = TSNE(n_components=2, random_state=42, perplexity=30)
coords_tsne = tsne.fit_transform(X_tsne_sample)

plt.figure(figsize=(10, 6))
sns.scatterplot(x=coords_tsne[:, 0], y=coords_tsne[:, 1], hue=labels_tsne_opt, palette='magma', alpha=0.7)
plt.title(f"2D t-SNE prikaz klastera (KMeans, K={optimal_k}) — Samo Tekst, uzorak 2000")
plt.tight_layout()
plt.savefig(os.path.join(output_dir,"tsne_2d_opt_textonly.png"), dpi=150)
plt.show()

plt.figure(figsize=(10, 6))
sns.scatterplot(x=coords_tsne[:, 0], y=coords_tsne[:, 1], hue=labels_tsne_k5, palette='tab10', alpha=0.7)
plt.title("2D t-SNE prikaz klastera (KMeans, K=5) — Samo Tekst, uzorak 2000")
plt.tight_layout()
plt.savefig(os.path.join(output_dir,"tsne_2d_k5_textonly.png"), dpi=150)
plt.show()

# --- 3D Vizualizacija - optimalni K ---
pca_3d = PCA(n_components=3)
X_3d = pca_3d.fit_transform(X_final)
df_3d = pd.DataFrame(X_3d, columns=['PC1', 'PC2', 'PC3'])
df_3d['Klaster'] = labels_km.astype(str)
df_3d['Snippet'] = df['Text'].str[:50]

fig = px.scatter_3d(
    df_3d, x='PC1', y='PC2', z='PC3',
    color='Klaster',
    title=f"3D Vizualizacija: Samo Tekst (K={optimal_k})",
    hover_data=['Snippet']
)
fig.show()

# --- 3D Vizualizacija - K=5 ---
df_3d_k5 = pd.DataFrame(X_3d, columns=['PC1', 'PC2', 'PC3'])
df_3d_k5['Klaster'] = labels_km5.astype(str)
df_3d_k5['Snippet'] = df['Text'].str[:50]

fig5 = px.scatter_3d(
    df_3d_k5, x='PC1', y='PC2', z='PC3',
    color='Klaster',
    title="3D Vizualizacija: Samo Tekst (K=5)",
    hover_data=['Snippet']
)
fig5.show()

print("\nGotovo! Svi grafici su sacuvani u folderu:", output_dir)
# Out:
# t-SNE vizualizacija (moze potrajati ~2-3 minuta)...
# <div>                            <div id="dbb9e21f-2c7d-4fe8-9ebb-0e5a0e54ec59" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dbb9e21f-2c7d-4fe8-9ebb-0e5a0e54ec59")) {                    Plotly.newPlot(                        "dbb9e21f-2c7d-4fe8-9ebb-0e5a0e54ec59",                        [{"customdata":[["My family has tried the Apple Cinnamon variety of "],["I feed this to her with a little cereal ...or by i"],["I am anxious to find salted\u002fcheese flavored snacks"],["I'm sorry, but I couldn't eat this one. It wasn't "],["I bought these since many people commented on how "],["Odd texture too.  I prefer the shrimp chips that a"],["We use this in place of white sugar. It does not g"],["It only gets one star because there wasn't anythin"],["My biggest gripe is... What moron taste tested thi"],["This is the most nacho cheesey sauce that you can "],["My family liked this.  The only other Mrs. Leeper'"],["Bought  this mainly out of curiosity after seeing "],["There is something off about this flavor, either t"],["Kay's Naturals are terrific. There is a wide varie"],["LOVE the orange (like orange soda, bubbly but not "],["I am addicted to sushi, which is an expensive addi"],["I bought this item based on such good reviews. I t"],["I had tried Fiber One and though I loved it, I was"],["I originally started taking Calm for the magnesium"],["We tried both the apple and the banana flavors and"],["If you hear \"multi grain\", you think cardboard.  N"],["These tastes like normal m&m's.  I can't taste any"],["I'm not sure why this item has such terrible revie"],["I love these crackers and even serve them to non G"],["I am the sort of mom who likes to bake my own cook"],["I read some of the reviews on here and I almost di"],["These blue chips are great to dip salsa into.  It "],["I have been drinking this tea for a while now. I l"],["this candy has very nice texture and are very deli"],["I bought a case of these from the Warehouse Deals "],["We bought these chips at a little sandwich shop in"],["Let me start off by saying that I did not expect t"],["I have tried a couple other brands of sugar free o"],["I didn't expect this to be this fizzy. Sure it's n"],["For a microwavable chili, this stuff, and the fire"],["If you love almonds - especially Blue Diamond Almo"],["Up until about 2 months ago, I was able to get the"],["Tasted great, I used another soda maker, not a Sod"],["Very good and tasty product. A little hotter than "],["The product is a high fiber, whole grain cereal ty"],["This is a tasty meal or treat and it comes with a "],["I have eaten the other pop chips and thought that "],["A tangy mustard vinegar sauce without being bitter"],["I was pretty psyched to be able to try a case of t"],["I have been addicted to this hot sauce for over 8 "],["Tart - then sweet - candy that tastes GREAT.  Nice"],["This is a great deal on the Subscribe and Save wit"],["Recently I've taken to trying out different brands"],["I bought these because I like the idea of a veggie"],["These are so good! They almost taste like cake! Gr"],["... and these do!!\u003cbr \u002f\u003e\u003cbr \u002f\u003eWow!  I was really s"],["As far as going natural this is very good, it is a"],["If you want a new way of preparing this pudding, t"],["It took two smoothies and now I'm hooked. I love N"],["These chips are really, really good.  I don't both"],["In all the time I've had my Keurig I've been searc"],["There is a nice mix of sizes, small and round or l"],["Hey, Kool-Aid! Kool-Aid was a fondly remembered pa"],["Positives:\u003cbr \u002f\u003e* Doesn't use artificial sweetener"],["I love Jones soda and Berry Lemonade is my favorit"],["I love these ginger candy, tastes like ginger noth"],["I bought this to make cinnamon toothpicks and ...
# <div>                            <div id="ec6bddc5-4012-4ea4-8947-968b550968fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec6bddc5-4012-4ea4-8947-968b550968fe")) {                    Plotly.newPlot(                        "ec6bddc5-4012-4ea4-8947-968b550968fe",                        [{"customdata":[["My family has tried the Apple Cinnamon variety of "],["I feed this to her with a little cereal ...or by i"],["These work great.  I now have great traction on al"],["My dog is a pretty intense chewer - and is about 1"],["the jerky was so tough i was only able to eat 1 ou"],["I have used them for years.  My dog can't wait to "],["These cost more on Amazon than the grocery store, "],["My son loves these for lunch at school and since m"],["My title says it all.  shop around and get it else"],["I bought this licorice on vacation and am excited "],["Pros:\u003cbr \u002f\u003e-Price *much less then what the stores "],["I ordered this product, \"Only Natural Apple Cider "],["I agree with the other reviewers regarding the pri"],["The pill pockets are grea. Perfect for my dogs med"],["I'm sorry, but I couldn't eat this one. It wasn't "],["My mother has bought this particular herb blend fo"],["I couldn't believe this kit when I first found it "],["We use this in place of white sugar. It does not g"],["These fortune cookies were a hit!  My sister LOVES"],["Great shelf life and you can make it so many diffe"],["A family member recently moved to a different coun"],["It only gets one star because there wasn't anythin"],["As an African-American woman who has suffered from"],["My biggest gripe is... What moron taste tested thi"],["This product is awesome and the price is not too h"],["This is the most nacho cheesey sauce that you can "],["These sunflower seeds are the hardest to find in a"],["I have tried other gf pastas and Tinkyada is top n"],["My family liked this.  The only other Mrs. Leeper'"],["My baby LOVED the Ella's kitchen items, especially"],["This popcorn leaves very few old maids. It's fresh"],["I sent these to my daughter who is away at college"],["Crunchy, flavorful, healthy . . . heaven!\u003cbr \u002f\u003e\u003cbr"],["Bought  this mainly out of curiosity after seeing "],["I mainly purchased because there was a great deal "],["Funny about the rave reviews here, don't get me wr"],["When I first went to order these I thought they we"],["There is something off about this flavor, either t"],["LOVE the orange (like orange soda, bubbly but not "],["I am addicted to sushi, which is an expensive addi"],["I bought this item based on such good reviews. I t"],["I first purchased these root beer drops from a loc"],["I have searched for good olive oil for years and o"],["I had gotten this product at a local health store "],["I usually don't write food reviews because, well, "],["I had tried Fiber One and though I loved it, I was"],["I received my first order of Earth's Best Vegetabl"],["I have been using this product instead of regular "],["I've been hunting for snacks which taste good, but"],["I originally started taking Calm for the magnesium"],["I eat popcorn almost every day.  I was disappointe"],["I use Amy & Brian Coconut Juice to make my Young C"],["We tried both the apple and the banana flavors and"],["If you hear \"multi grain\", you think cardboard.  N"],["I too purchased these on a Friday sale, six bags f"],["I love these crackers and even serve them to non G"],["I am the sort of mom who likes to bake my own cook"],["I read some of the reviews on here and I almost di"],["A great substitute for pasta. No calories so you c"],["My dog-Chloe Cupcake-absolutely loves this toy! Wh"],["This is a fairly decent, commercial berbere mixtur"],["It's a good item to have in the pantry for a rainy"],["The  ...
# Gotovo! Svi grafici su sacuvani u folderu: grafici_text_only
